# %% [markdown]
# # Exploring the Lovecraft Corpus - Topic Modeling
# Ryan Folks
# vcz2aj@virginia.edu
#
# ### Objective: The objective of this notebook is to apply [latent dirichlet allocation](https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation) to the lovecraft corpus.
# ---

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import LatentDirichletAllocation as LDA, NMF
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %% [markdown]
# ## Prepare Data

# %%
np.random.seed(5)
n_terms = 1000
n_topics = 15 # lovecraft's work isn't varied enough for too many topics. More than 10 and there might be story-specific topics.
max_iter = 20
# n_top_terms = 7
doc_topic_prior = .1 # Prior of document topic distribution alpha. Defaults to 1 / n_components.
topic_word_prior = .1 # Prior of topic word distribution beta. Defaults to 1 / n_components.

# %%
data_home = 'data'
data_prefix = 'lovecraft_'
BAG = ['title']
BOW = pd.read_csv(f'{data_home}/output/{data_prefix}BOW.csv').set_index(BAG+['term_str'])
LIB = pd.read_csv(f'{data_home}/output/{data_prefix}LIB.csv').set_index('title')

# %%
class TopicModel():            

    bow_count_col:str = 'n'
    n_topics:int = 20
    n_top_terms:int = None
    engine_type = 'LDA' # Also NMF
    n_terms = 1000

    # LDA Params
    max_iter:int = 20
    learning_offset:float = 50.
    random_state:int = 0
    
    # NMF Params
    nmf_init = 'nndsvd'
    nmf_max_iter = 1000
    
    def __init__(self, BOW:pd.DataFrame):
        self.BOW = BOW
        self.LIB = LIB
        
    def create_X(self):
        X = self.BOW[self.bow_count_col].unstack()
        V = X.count().to_frame('df')
        X = X.fillna(0)
        V['idf'] = np.log2(len(X)/V.df)
        V['dfidf'] = V.df * V.idf
        SIGS = V.sort_values('dfidf', ascending=False).head(self.n_terms).index
        self.X = X[SIGS]
        self.V = V              
        
    def get_model(self):
        
        if self.engine_type == 'LDA':
            self.engine = LDA(n_components=self.n_topics, 
                                  max_iter=self.max_iter, 
                                  learning_offset=self.learning_offset, 
                                  random_state=self.random_state)

        elif self.engine_type == 'NMF':
            self.engine = NMF(n_components=self.n_topics, 
                                  max_iter=self.nmf_max_iter,
                                  init=self.nmf_init, 
                                  random_state=1, 
                                  alpha=.1, 
                                  l1_ratio=.5)
                
        self.THETA = pd.DataFrame(self.engine.fit_transform(self.X.values), index=self.X.index)
        self.THETA.columns.name = 'topic_id'
        
        self.PHI = pd.DataFrame(self.engine.components_, columns=self.X.columns)
        self.PHI.index.name = 'topic_id'
        self.PHI.columns.name = 'term_str'
        
        self.TOPIC = self.PHI.sum(1).to_frame('phi_sum')
        self.TOPIC['theta_sum'] = self.THETA.sum()

    def describe_topics(self):
        
        PHI_P = (self.PHI.T / self.PHI.T.sum())
        PHI_I = np.log2(1/PHI_P)
        self.TOPIC['h'] = round((PHI_I * PHI_P).sum().sort_values(ascending=False), 2)
        if not self.n_top_terms:
            self.n_top_terms = round(self.TOPIC.h.mean())
            
        # Compute relevant terms
        self.get_relevant_terms(0)            

        self.TOPIC['top_terms'] = self.PHI.stack().to_frame('topic_weight')\
            .groupby('topic_id')\
            .apply(lambda x: 
                x.sort_values('topic_weight', ascending =False)\
                    .head(self.n_top_terms)\
                    .reset_index()['term_str'])\
            .apply(lambda x: ' '.join(x.replace(' ', '_')), 1)
        
        # Not using top terms from above; using from get_relevant_terms()
        self.TOPIC['label'] = self.TOPIC.apply(lambda x: f"{x.name}: {x.top_terms_rel}", 1)
                
    def get_relevant_terms(self, 𝜆 = .5):
        """
        Compute relevance of topic terms as defined by Sievert and Shirley 2014.
        C. Sievert and K. Shirley, “LDAvis: A Method for Visualizing and Interpreting Topics,” 
        in Proceedings of the workshop on interactive language learning, visualization, and interfaces, 2014, pp. 63–70.
        """
        Ptw = self.PHI.apply(lambda x: x / x.sum(), 1) # L1 norm of PHI rows, i.e. p(w|t)
        Pw = self.PHI.sum() / self.PHI.sum().sum() # Marginal probs of terms in PHI, i.e. p(w)
        self.REL = 𝜆 * np.log2(Ptw) + (1-𝜆) * np.log2(Ptw / Pw)
        self.TOPIC['top_terms_rel'] = self.REL.apply(lambda x: ' '.join(x.sort_values(ascending=False).head(self.n_top_terms).index), 1)

    def get_model_stats(self):
        # p = self.TOPIC.theta_sum / self.TOPIC.theta_sum.sum()
        self.entropy = self.TOPIC.h.sum()
        self.redundancy = 1 - self.entropy / np.log2(self.n_topics)
    
    def get_doc_stats(self):
        self.DOC = (self.THETA.T * np.log2(1/self.THETA.T)).sum().to_frame('entropy')
        self.DOC['max_topic'] = self.THETA.idxmax(1)
        
    def plot_topics(self):
        self.TOPIC.sort_values('theta_sum', ascending=True).plot.barh(y='theta_sum', x='label', figsize=(5, self.n_topics/2))

# %% [markdown]
# ## Make Model

# %%
BOW
# Out:
#                                      n        tf     tfidf
# title                term_str
# a garden             !               1  0.004566  0.000822
#                      ,              13  0.059361  0.000000
#                      .               4  0.018265  0.000147
#                      :               2  0.009132  0.002571
#                      ;               2  0.009132  0.000148
# ...                                 ..       ...       ...
# what the moon brings would           2  0.002635  0.000443
#                      writhing        1  0.001318  0.001174
#                      yellow          2  0.002635  0.001403
#                      yellow-litten   1  0.001318  0.002684
#                      yet             1  0.001318  0.000199
#
# [130334 rows x 3 columns]

# %%
tm_hp = TopicModel(BOW)
tm_hp.n_topics = n_topics
tm_hp.engine_type = 'LDA'
tm_hp.create_X()
tm_hp.get_model()
tm_hp.describe_topics()
tm_hp.get_model_stats()
tm_hp.get_doc_stats()

# %%
tm_hp.DOC = BOW.groupby(['title']).n.sum().to_frame().join(LIB['category'])
tm_hp.DOC['label'] = tm_hp.DOC.apply(lambda x: f"{x.name[:30]} ({x.category[:1]})", 1)

# %%
tm_hp.DOC
# Out:
#                                                         n     category  \
# title
# a garden                                              219         poem
# an american to mother england                         581         poem
# arcadia                                                87         poem
# astrophobos                                           291         poem
# at the mountains of madness                         45410  short story
# ...                                                   ...          ...
# to clark ashton smith, esq., upon his phantasti...    132         poem
# to edward john moreton drax plunkett, eighteent...    613         poem
# unda; or, the bride of the sea                        817         poem
# waste paper a poem of profound insignificance        1117         poem
# what the moon brings                                  759  short story
#
#                                                                                  label
# title
# a garden                                                                  a garden (p)
# an american to mother england                        an american to mother england (p)
# arcadia                                                                    arcadia (p)
# astrophobos                                                            astrophobos (p)
# at the mountains of madness                            at the mountains of madness (s)
# ...                                                                                ...
# to clark ashton smith, esq., upon his phantasti...  to clark ashton smith, esq., u (p)
# to edward john moreton drax plunkett, eighteent...  to edward john moreton drax pl (p)
# unda; or, the bride of the sea                      unda; or, the bride of the sea (p)
# waste paper a poem of profound insignificance       waste paper a poem of profound (p)
# what the moon brings                                          what the moon brings (s)
#
# [109 rows x 3 columns]

# %%
tm_hp.plot_topics()

# %%
HP_IMG = tm_hp.THETA.groupby('title').mean()
HP_IMG.index = tm_hp.DOC.label
HP_IMG.columns = tm_hp.TOPIC.label

# %% [markdown]
# Take out topic 1 and softmax the rest.

# %%
def normalize_line(series):
    return series/np.sum(series)

# %%
temp_img = HP_IMG.copy()
temp_img.drop(columns = '14: ’ d s er ring bright beams o :', inplace=True)
temp_img = temp_img.apply(lambda x: normalize_line(x), axis=1)
temp_img
# Out:
# label                               0: bit flame climbed fire meant sign glow truth free  \
# title
# a garden (p)                                                                 0.071428
# an american to mother england (p)                                            0.007389
# arcadia (p)                                                                  0.003937
# astrophobos (p)                                                              0.071429
# at the mountains of madness (s)                                              0.000007
# ...                                                                               ...
# to clark ashton smith, esq., u (p)                                           0.003970
# to edward john moreton drax pl (p)                                           0.001800
# unda; or, the bride of the sea (p)                                           0.071428
# waste paper a poem of profound (p)                                           0.000562
# what the moon brings (s)                                                     0.000454
#
# label                               1: gods clouds grey wood carven twilight climb wise temple  \
# title
# a garden (p)                                                                 0.071429
# an american to mother england (p)                                            0.007389
# arcadia (p)                                                                  0.003937
# astrophobos (p)                                                              0.071429
# at the mountains of madness (s)                                              0.002058
# ...                                                                               ...
# to clark ashton smith, esq., u (p)                                           0.948390
# to edward john moreton drax pl (p)                                           0.336379
# unda; or, the bride of the sea (p)                                           0.071429
# waste paper a poem of profound (p)                                           0.000562
# what the moon brings (s)                                                     0.000454
#
# label                               2: regions village sky played abyss commenced somewhere walked sought  \
# title
# a garden (p)                                                                 0.071428
# an american to mother england (p)                                            0.007389
# arcadia (p)                                                                  0.003937
# astrophobos (p)                                                              0.071428
# at the mountains of madness (s)                                              0.000007
# ...                                                                               ...
# to clark ashton smith, esq., u (p)                                           0.003970
# to edward john moreton drax pl (p)                                           0.001800
# unda; or, the bride of the sea (p)                                           0.071429
# waste paper a poem of profound (p)                                           0.000562
# what the moon brings (s)                                                     0.000454
#
# label                               3: we us our hundred thousand five height necessary land  \
# title
# a garden (p)                                                                 0.071429
# an american to mother england (p)                                            0.007389
# arcadia (p)                                                                  0.003937
# astrophobos (p)                                                              0.071429
# at the mountains of madness (s)                                              0.674880
# ...                                                                               ...
# to clark ashton smith, esq., u (p)                                           0.003970
# to edward john moreton drax pl (p)                                           0.221149
# unda; or, the bride of the sea (p)                                           0.071429
# waste paper a poem of profound (p)                                           0.000562
# what the moon brings (s)                                                     0.000454
#
# label                               4: race position slightly dreaded abysses events experience fury future  \
# title
# a garden (p)                                                                 0.071429
# an american to mother england (p)                                            0.007389
# arcadia (p)                                                                  0.003937
# astrophobos (p)                                                              0.071429
# at the mountains of madness (s)                                              0.319430
# ...                                                                               ...
# to clark ashton smith, esq., u (p)                                           0.003970
# to edward john moreton drax pl (p)                                           0.001800
# unda; or, the bride of the sea (p)                                           0.071429
# waste paper a poem of profound (p)                                           0.000562
# what the moon brings (s)                                                     0.000454
#
# label                               5: she you ) your ( her picture get different  \
# title
# a garden (p)                                                             0.071429
# an american to mother england (p)                                        0.007389
# arcadia (p)                                                              0.003937
# astrophobos (p)                                                          0.071429
# at the mountains of madness (s)                                          0.003560
# ...                                                                           ...
# to clark ashton smith, esq., u (p)                                       0.003970
# to edward john moreton drax pl (p)                                       0.001800
# unda; or, the bride of the sea (p)                                       0.071429
# waste paper a poem of profound (p)                                       0.762839
# what the moon brings (s)                                                 0.000454
#
# label                               6: bringing gazed wildest damnable madly sank cursed troubled shudder  \
# title
# a garden (p)                                                                 0.071428
# an american to mother england (p)                                            0.007389
# arcadia (p)                                                                  0.003937
# astrophobos (p)                                                              0.071428
# at the mountains of madness (s)                                              0.000007
# ...                                                                               ...
# to clark ashton smith, esq., u (p)                                           0.003970
# to edward john moreton drax pl (p)                                           0.001800
# unda; or, the bride of the sea (p)                                           0.071428
# waste paper a poem of profound (p)                                           0.000562
# what the moon brings (s)                                                     0.000454
#
# label                               7: ' o n't got road guess boy shut water  \
# title
# a garden (p)                                                        0.071429
# an american to mother england (p)                                   0.007389
# arcadia (p)                                                         0.389682
# astrophobos (p)                                                     0.071429
# at the mountains of madness (s)                                     0.000007
# ...                                                                      ...
# to clark ashton smith, esq., u (p)                                  0.003970
# to edward john moreton drax pl (p)                                  0.001800
# unda; or, the bride of the sea (p)                                  0.071429
# waste paper a poem of profound (p)                                  0.000562
# what the moon brings (s)                                            0.000454
#
# label                               8: key waves ultimate shapes gate worlds book cosmic reality  \
# title
# a garden (p)                                                                 0.071429
# an american to mother england (p)                                            0.007389
# arcadia (p)                                                                  0.003937
# astrophobos (p)                                                              0.071429
# at the mountains of madness (s)                                              0.000007
# ...                                                                               ...
# to clark ashton smith, esq., u (p)                                           0.003970
# to edward john moreton drax pl (p)                                           0.001800
# unda; or, the bride of the sea (p)                                           0.071429
# waste paper a poem of profound (p)                                           0.000562
# what the moon brings (s)                                                     0.000454
#
# label                               9: marble waters beheld lives beauty laughed curse moon dwelt  \
# title
# a garden (p)                                                                 0.071429
# an american to mother england (p)                                            0.551563
# arcadia (p)                                                                  0.003937
# astrophobos (p)                                                              0.071429
# at the mountains of madness (s)                                              0.000007
# ...                                                                               ...
# to clark ashton smith, esq., u (p)                                           0.003970
# to edward john moreton drax pl (p)                                           0.422676
# unda; or, the bride of the sea (p)                                           0.071429
# waste paper a poem of profound (p)                                           0.092125
# what the moon brings (s)                                                     0.994102
#
# label                               10: stream sun spread worlds ways fears seat s shadows  \
# title
# a garden (p)                                                                 0.071429
# an american to mother england (p)                                            0.007389
# arcadia (p)                                                                  0.059034
# astrophobos (p)                                                              0.071429
# at the mountains of madness (s)                                              0.000007
# ...                                                                               ...
# to clark ashton smith, esq., u (p)                                           0.003970
# to edward john moreton drax pl (p)                                           0.001800
# unda; or, the bride of the sea (p)                                           0.071429
# waste paper a poem of profound (p)                                           0.000562
# what the moon brings (s)                                                     0.000454
#
# label                               11: west bodies unnatural fresh grave ghastly killed disappeared natural  \
# title
# a garden (p)                                                                 0.071429
# an american to mother england (p)                                            0.359769
# arcadia (p)                                                                  0.003937
# astrophobos (p)                                                              0.071429
# at the mountains of madness (s)                                              0.000007
# ...                                                                               ...
# to clark ashton smith, esq., u (p)                                           0.003970
# to edward john moreton drax pl (p)                                           0.001800
# unda; or, the bride of the sea (p)                                           0.071429
# waste paper a poem of profound (p)                                           0.000562
# what the moon brings (s)                                                     0.000454
#
# label                               12: library court street century aged family youth father mother  \
# title
# a garden (p)                                                                 0.071429
# an american to mother england (p)                                            0.007389
# arcadia (p)                                                                  0.507977
# astrophobos (p)                                                              0.071429
# at the mountains of madness (s)                                              0.000007
# ...                                                                               ...
# to clark ashton smith, esq., u (p)                                           0.003970
# to edward john moreton drax pl (p)                                           0.001800
# unda; or, the bride of the sea (p)                                           0.071429
# waste paper a poem of profound (p)                                           0.138857
# what the moon brings (s)                                                     0.000454
#
# label                               13: bringing gazed wildest damnable madly sank cursed troubled shudder
# title
# a garden (p)                                                                 0.071428
# an american to mother england (p)                                            0.007389
# arcadia (p)                                                                  0.003937
# astrophobos (p)                                                              0.071428
# at the mountains of madness (s)                                              0.000007
# ...                                                                               ...
# to clark ashton smith, esq., u (p)                                           0.003970
# to edward john moreton drax pl (p)                                           0.001800
# unda; or, the bride of the sea (p)                                           0.071428
# waste paper a poem of profound (p)                                           0.000562
# what the moon brings (s)                                                     0.000454
#
# [109 rows x 14 columns]

# %%
temp_img.T.style.background_gradient(cmap='GnBu')
# Out:
# <style  type="text/css" >
# 4         race position slightly dreaded abysses events ...
# 5                she you ) your ( her picture get different
# 6         bringing gazed wildest damnable madly sank cur...
# 7                     ' o n't got road guess boy shut water
# 8         key waves ultimate shapes gate worlds book cos...
# 9         marble waters beheld lives beauty laughed curs...
# 10        stream sun spread worlds ways fears seat s sha...
# 11        west bodies unnatural fresh grave ghastly kill...
# 12        library court street century aged family youth...
# 13        bringing gazed wildest damnable madly sank cur...
# 14                           ’ d s er ring bright beams o :
#
#                                                   top_terms  \
# topic_id
# 0          bit meant elder ago tried climbed door sign hill
# 1              gods city earth grey way even sea stone cold
# 2         sky village city abyss sea dreams regions drea...
# 3                   we our us even land city feet course ``
# 4         even certain felt thought most since two almost ?
# 5                           you `` she her do n't ? '' even
# 6         future deeper wildest hint pit magic cut remai...
# 7                              ' n't o `` ... do ? kind got
# 8                    `` you '' key ? earth has dreams being
# 9            moon city land dreams shall `` green sea white
# 10             ’ s sun ? evening ways shadows stream worlds
# 11              we west our dead us fresh body bodies human
# 12            ' house street door most two much town little
# 13        future deeper wildest hint pit magic cut remai...
# 14                                ’ d s : er o her our ring
#
#                                                       label
# topic_id
# 0         0: bit flame climbed fire meant sign glow trut...
# 1         1: gods clouds grey wood carven twilight climb...
# 2         2: regions village sky played abyss commenced ...
# 3         3: we us our hundred thousand five height nece...
# 4         4: race position slightly dreaded abysses even...
# 5             5: she you ) your ( her picture get different
# 6         6: bringing gazed wildest damnable madly sank ...
# 7                  7: ' o n't got road guess boy shut water
# 8         8: key waves ultimate shapes gate worlds book ...
# 9         9: marble waters beheld lives beauty laughed c...
# 10        10: stream sun spread worlds ways fears seat s...
# 11        11: west bodies unnatural fresh grave ghastly ...
# 12        12: library court street century aged family y...
# 13        13: bringing gazed wildest damnable madly sank...
# 14                       14: ’ d s er ring bright beams o :

# %%
fig = px.imshow(temp_img, color_continuous_scale='GnBu', title="LOVECRAFT", height=3000, width=1000)
fig.update_layout(xaxis={'side': 'top', 'title_text':None}, yaxis={'title_text':None},)

# %% [markdown]
# ## Topics Across Time

# %%
LIB
# Out:
#                                                                                              filepath  \
# title
# the alchemist                                                        data/short_stories\alchemist.txt
# facts concerning the late arthur jermyn and his...               data/short_stories\arthur_jermyn.txt
# azathoth                                                              data/short_stories\azathoth.txt
# the beast in the cave                                                    data/short_stories\beast.txt
# beyond the wall of sleep                                  data/short_stories\beyond_wall_of_sleep.txt
# ...                                                                                               ...
# the wood                                                                     data/poetry\The Wood.txt
# to clark ashton smith, esq., upon his phantasti...  data/poetry\To Clark Ashton Smith, Esq., upon ...
# to edward john moreton drax plunkett, eighteent...  data/poetry\To Edward John Moreton Drax Plunke...
# unda; or, the bride of the sea                         data/poetry\Unda; or, The Bride of the Sea.txt
# waste paper a poem of profound insignificance                             data/poetry\Waste Paper.txt
#
#                                                     date     category
# title
# the alchemist                                       1908  short story
# facts concerning the late arthur jermyn and his...  1920  short story
# azathoth                                            1922  short story
# the beast in the cave                               1905  short story
# beyond the wall of sleep                            1919  short story
# ...                                                  ...          ...
# the wood                                            1929         poem
# to clark ashton smith, esq., upon his phantasti...  1936         poem
# to edward john moreton drax plunkett, eighteent...  1919         poem
# unda; or, the bride of the sea                      1915         poem
# waste paper a poem of profound insignificance       1923         poem
#
# [109 rows x 3 columns]

# %%
temp = pd.DataFrame(HP_IMG).copy()
temp.index.rename('title', inplace=True)
title_temp = LIB.copy()
lib_temp = LIB.copy()
title_temp.reset_index(inplace=True)
title_temp = title_temp.apply(lambda x: f"{x.title[:30]} ({x.category[:1]})", 1).copy()
lib_temp.index = title_temp

temp = temp.join(lib_temp)

# %%
temp = temp[temp['date'] != 'N.D']

# %%
temp = temp.sort_values(by='date')

# %%
from scipy.signal import savgol_filter

# %%
# Out:
# array([ 1.53837244e-04,  2.86503374e-04,  4.74496309e-04,  7.03561702e-04,
#         9.59445205e-04,  1.48635501e-03,  1.55239956e-03,  1.45310815e-03,
#         1.10362003e-03,  9.92049242e-04,  1.57097325e-03,  1.62985474e-03,
#         1.25952724e-03,  1.37733883e-03,  1.00683001e-03,  5.71543082e-04,
#         2.02344745e-04,  4.93673531e-04,  5.60620604e-04,  5.65529382e-04,
#         4.52486852e-04,  4.90660871e-04,  4.01600682e-04,  2.41963376e-04,
#         3.19073908e-04,  4.27485461e-04,  3.94606443e-04,  2.21426996e-04,
#         2.68112906e-04,  4.48030478e-04,  4.21787347e-04,  4.27877034e-04,
#         4.10828526e-04,  9.79145218e-04,  1.26018799e-03,  1.23774081e-03,
#         1.22920533e-03,  1.11912154e-03,  7.03032917e-04,  2.51637226e-04,
#        -1.39288349e-04,  1.56500862e-04,  1.71095396e-04,  1.53080990e-04,
#        -4.31190110e-04,  6.03759901e-04,  1.30313561e-03,  1.71081294e-03,
#         1.77402085e-03,  1.65048880e-03,  1.25753691e-03,  5.57993708e-04,
#        -4.09831906e-04,  1.90940533e-04,  1.36894150e-04,  1.59809036e-04,
#         1.33763401e-04,  1.26667505e-04,  2.07407129e-04,  2.36671338e-04,
#         2.46348413e-04,  2.16026870e-04,  1.35376419e-04,  1.76954491e-04,
#         1.49854265e-04,  9.59401361e-05,  1.37682731e-04, -7.09231046e-05,
#         9.13126151e-05,  4.85190608e-04,  7.38417716e-04,  8.98519603e-04,
#         9.09467799e-04,  6.54855516e-04,  5.11878291e-04,  1.71076613e-04,
#         1.98858273e-04,  3.28158868e-04,  3.19543718e-04,  2.45115626e-04,
#         1.99968833e-04,  6.81397614e-05,  1.81719625e-04,  1.67492469e-04,
#        -8.02831487e-02,  5.35973214e-02,  1.49257903e-01,  2.06859006e-01,
#         2.26392100e-01,  2.07461350e-01,  1.50120166e-01,  5.43472746e-02,
#        -7.98527050e-02,  2.15501865e-04, -4.96283012e-05, -8.95013524e-05,
#         2.94395836e-05,  3.60324885e-05,  7.93078537e-05, -1.41351861e-03,
#         1.11183814e-03,  2.54739533e-03,  3.95321359e-03,  4.90802219e-03,
#         5.36266560e-03,  4.99395740e-03,  3.59089085e-03,  9.42459217e-04])

# %%
fig = make_subplots(rows=n_topics - 1, cols=1,
                    subplot_titles = ['topic ' + str(i) + ': ' + str(temp.columns[i]) for i in range(n_topics-1)])
for i in range(n_topics-1):
    topic = temp.columns[i]
    fig.add_trace(
        go.Scatter(x=temp[[topic, 'date']].date,
            y=savgol_filter(list(temp[[topic, 'date']][topic]), 25, 5)),
            row=i+1, col=1)

# %%
fig.update_layout(height=3000)
fig.show()
