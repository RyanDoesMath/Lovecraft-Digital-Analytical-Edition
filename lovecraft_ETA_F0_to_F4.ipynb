# %% [markdown]
# # Exploring the Lovecraft Corpus - Data Processing
# Ryan Folks
# vcz2aj@virginia.edu
#
# ### Objective: The objective of this notebook is to synthesize an F0 dataset out of several sources and transform it into an F4 dataset.
# ---

# %%
import glob
import pandas as pd
import numpy as np
import nltk
from tqdm import tqdm

# %% [markdown]
# ---

# %% [markdown]
# # 0) Decisions in Building this Digital Analytical Edition

# %% [markdown]
# Anytime I make a conscientious decision in the building of this digital analytical edition, I want to preserve that so that it can be reversed/changed, and understood by others who use this for academic purposes.
#
# ## Decision Log:
#
# 1. Changed the title of <ins>Celephaïs</ins> to <ins>Celephais</ins> (with one dot over the 'i') for easier data cleaning and indexing.
# 2. Changed the title of <ins>Herbert West — Reanimator</ins> to <ins>Herbert West: Reanimator</ins> because of potential confusion between the minus sign (-) and hyphen (—)
# 3. Listed the date of <ins>The Crawling Chaos</ins> as 1921, but it is unclear whether it was written in 1920 or 1921.
# 4. Fixed/changed the title of <ins>Dreams in the Witch-House</ins> in the lovecraft corpus to <ins>**The** Dreams in the Witch House</ins>.
# 5. Listed the date of <ins>Through the Gates of the Silver Key</ins> as 1933, when in reality it was started in 1932.
# 6. Fixed the title of <ins>Poetry of the Gods</ins> in the lovecraft corpus to <ins>Poetry **and** the Gods</ins>.
# 7. <ins>Christmas</ins>'s date is unknown, but it is listed as 1920, since this was the date it was published in a magazine.
# 8. <ins>Nathicana</ins>'s date is unknown, but was first published in 1927.
# 9. <ins>Psychopompos: A Tale in Rhyme</ins> might have been written in 1917, but it is listed as 1918.
# 10. <ins>Waste Paper</ins> may have been written in late 1922, but it is listed as 1923.
# 11.

# %% [markdown]
# ## Sources:
# The sources of information that I have used.
# 1. https://hplovecraft.com/writings/texts/
# 2. https://en.wikipedia.org/wiki/H._P._Lovecraft_bibliography
# 3. https://github.com/vilmibm/lovecraftcorpus
# 4. https://github.com/ontoligent/DS5001-2022-01

# %% [markdown]
# ---

# %% [markdown]
# ## 1) Building the Corpus

# %% [markdown]
# ## Extracting Stories and their Titles

# %%
lovecraft_dict = {}
for i in glob.glob('data/short_stories/*.txt'):
    story = open(i, 'r').readlines()
    title = ' '.join([i for i in str(story[0]).replace('\n', '').lower().split()])
    story = ' '.join(story)
    story = story.split('\n \n')[1:]
    lovecraft_dict[title] = ' '.join(story)

# %%
stories_df = pd.DataFrame([lovecraft_dict.keys(), lovecraft_dict.values()]).transpose()
stories_df.columns = ['title', 'content']
stories_df.set_index('title', inplace=True)

# %%
stories_df
# Out:
#                                                                                               content
# title
# the alchemist                                        High up, crowning the grassy summit of a swel...
# facts concerning the late arthur jermyn and his...   I  Life is a hideous thing, and from the back...
# azathoth                                             When age fell upon the world, and wonder went...
# the beast in the cave                                The horrible conclusion which had been gradua...
# beyond the wall of sleep                             I have often wondered if the majority of mank...
# ...                                                                                               ...
# the unnamable                                        With this friend, Joel Manton, I had often la...
# in the vault                                         Birch acquired a limitation and changed his b...
# what the moon brings                                 It was in the spectral summer when the moon s...
# the whisperer in darkness                            I  Bear in mind closely that I did not see an...
# the white ship                                       I am Basil Elton, keeper of the North Point l...
#
# [67 rows x 1 columns]

# %%
stories_df['filepath'] = [i for i in glob.glob('data/short_stories/*.txt')]

# %%
stories_df
# Out:
#                                                                                               content  \
# title
# the alchemist                                        High up, crowning the grassy summit of a swel...
# facts concerning the late arthur jermyn and his...   I  Life is a hideous thing, and from the back...
# azathoth                                             When age fell upon the world, and wonder went...
# the beast in the cave                                The horrible conclusion which had been gradua...
# beyond the wall of sleep                             I have often wondered if the majority of mank...
# ...                                                                                               ...
# the unnamable                                        With this friend, Joel Manton, I had often la...
# in the vault                                         Birch acquired a limitation and changed his b...
# what the moon brings                                 It was in the spectral summer when the moon s...
# the whisperer in darkness                            I  Bear in mind closely that I did not see an...
# the white ship                                       I am Basil Elton, keeper of the North Point l...
#
#                                                                                        filepath
# title
# the alchemist                                                  data/short_stories\alchemist.txt
# facts concerning the late arthur jermyn and his...         data/short_stories\arthur_jermyn.txt
# azathoth                                                        data/short_stories\azathoth.txt
# the beast in the cave                                              data/short_stories\beast.txt
# beyond the wall of sleep                            data/short_stories\beyond_wall_of_sleep.txt
# ...                                                                                         ...
# the unnamable                                                  data/short_stories\unnamable.txt
# in the vault                                                       data/short_stories\vault.txt
# what the moon brings                                    data/short_stories\what_moon_brings.txt
# the whisperer in darkness                                      data/short_stories\whisperer.txt
# the white ship                                                data/short_stories\white_ship.txt
#
# [67 rows x 2 columns]

# %% [markdown]
# ## Getting Dates for the Stories

# %% [markdown]
# As far as I can tell, these dates mark the date of when Lovecraft *completed* these stories as opposed to when they were published. It is more important to list them this way since, analytically, we wist to see how his writing developed over time.

# %%
dates = '''The Beast in the Cave (1905)
    The Alchemist (1908)
    The Tomb (1917)
    Dagon (1917)
    Polaris (1918)
    Beyond the Wall of Sleep (1919)
    Memory (1919)
    Old Bugs (1919)
    The Transition of Juan Romero (1919)
    The White Ship (1919)
    The Doom That Came to Sarnath (1919)
    The Statement of Randolph Carter (1919)
    The Terrible Old Man (1920)
    The Tree (1920)
    The Cats of Ulthar (1920)
    The Temple (1920)
    Facts Concerning the Late Arthur Jermyn and His Family (1920)
    The Street (1920)
    Celephais (1920)
    From Beyond (1920)
    Nyarlathotep (1920)
    The Picture in the House (1920)
    Poetry and the Gods (1920)
    Ex Oblivione (1921)
    The Nameless City (1921)
    The Quest of Iranon (1921)
    The Moon-Bog (1921)
    The Outsider (1921)
    The Other Gods (1921)
    The Music of Erich Zann (1921)
    The Crawling Chaos (1921)
    Herbert West: Reanimator (1922)
    Hypnos (1922)
    What the Moon Brings (1922)
    Azathoth (1922)
    The Hound (1922)
    The Horror at Martin's Beach (1922)
    The Lurking Fear (1922)
    The Rats in the Walls (1923)
    The Unnamable (1923)
    The Festival (1923)
    The Shunned House (1924)
    Imprisoned with the Pharaohs (1924)
    The Horror at Red Hook (1925)
    He (1925)
    In the Vault (1925)
    The Descendant (1926)
    Cool Air (1926)
    The Call of Cthulhu (1926)
    Pickman's Model (1926)
    The Silver Key (1926)
    The Strange High House in the Mist (1926)
    The Dream-Quest of Unknown Kadath (1927)
    The Case of Charles Dexter Ward (1927)
    The Colour Out of Space (1927)
    The Very Old Folk (1927)
    The Thing in the Moonlight (1927)
    The History of the Necronomicon (1927)
    Ibid (1928)
    The Dunwich Horror (1928)
    Medusa's Coil (1930)
    The Whisperer in Darkness (1930)
    At the Mountains of Madness (1931)
    The Shadow Over Innsmouth (1931)
    The Dreams in the Witch House (1932)
    Through the Gates of the Silver Key (1933)
    The Thing on the Doorstep (1933)
    The Evil Clergyman (1933)
    The Book (1933)
    The Shadow out of Time (1934)
    The Haunter of the Dark (1935)'''

# %%
dates = dates.split('\n')
dates = [i.lstrip() for i in dates]
dates = [i.lower() for i in dates]
dates = {i.split('(')[0].rstrip():i.split('(')[1].replace(')', '') for i in dates}

# %%
dates = pd.DataFrame(dates, index=[0]).transpose()
dates.columns = ['date']
dates.index.rename('title', inplace=True)

# %%
dates
# Out:
#                            date
# title
# the beast in the cave      1905
# the alchemist              1908
# the tomb                   1917
# dagon                      1917
# polaris                    1918
# ...                         ...
# the thing on the doorstep  1933
# the evil clergyman         1933
# the book                   1933
# the shadow out of time     1934
# the haunter of the dark    1935
#
# [71 rows x 1 columns]

# %% [markdown]
# ## Merging Dates and Stories

# %%
hp_df = stories_df.merge(dates, how='left', right_index=True, left_index=True)

# %%
hp_df['category'] = 'short story'

# %% [markdown]
# ## Extracting Poems and their Titles

# %%
poem_dict = {}
for i in glob.glob('data/poetry/*.txt'):
    poem = open(i, 'r', encoding='utf-8').readlines()
    title = poem[0].split(': ')[1:][0].replace('\n', '')
    poem = ' '.join(poem).split('+++\n')[1]
    poem_dict[title.lower()] = poem

date_dict = {}
for i in glob.glob('data/poetry/*.txt'):
    poem = open(i, 'r', encoding='utf-8').readlines()
    title = poem[0].split(': ')[1:][0].replace('\n', '')
    date = poem[2].split(': ')[1]
    date_dict[title.lower()] = date.replace('\n', '')

# %%
poems_df = pd.DataFrame(poem_dict, index=[0]).transpose()
poems_df.columns = ['content']
poems_df['category'] = 'poem'

# %%
poems_df['filepath'] = [i for i in glob.glob('data/poetry/*.txt')]

# %%
dates_df = pd.DataFrame(date_dict, index=[0]).transpose()
dates_df.columns = ['date']

# %%
print(len(poems_df), len(dates_df), len(poems_df.merge(dates_df, right_index=True, left_index=True)))
poems_df = poems_df.merge(dates_df, right_index=True, left_index=True)
poems_df.index.rename('title', inplace=True)
# Out:
# 42 42 42

# %%
poems_df
# Out:
#                                                                                               content  \
# title
# a garden                                             There’s an ancient, ancient garden that I see...
# an american to mother england                        England! My England! Can the surging sea\n Th...
# arcadia                                              By Head Balledup\n \n O give me the life of t...
# astrophobos                                          In the midnight heavens burning\n \tThro’ eth...
# christmas                                            The cottage hearth beams warm and bright,\n \...
# dead passion's flame                                 A Poem by Blank Frailty\n \n Ah, Passion, lik...
# despair                                              O’er the midnight moorlands crying,\n Thro’ t...
# fact and fancy                                       How dull the wretch, whose philosophic mind\n...
# festival                                             \tThere is snow on the ground,\n \t\tAnd the ...
# fungi from yuggoth                                   I. The Book\n \n The place was dark and dusty...
# hallowe'en in a suburb                               The steeples are white in the wild moonlight,...
# in a sequester’d providence churchyard where on...   Eternal brood the shadows on this ground,\n D...
# laeta; a lament                                      Respectfully Dedicated to Rheinhart Kleiner, ...
# life’s mystery                                       Life! Ah, Life!\n What may this fluorescent p...
# lines on gen. robert edward lee                      \t“Si veris magna paratur\n Fama bonis, et si...
# nathicana                                            It was in the pale garden of Zaïs;\n The mist...
# nemesis                                              \tThro’ the ghoul-guarded gateways of slumber...
# ode for july fourth, 1917                            As Columbia’s brave scions, in anger array’d,...
# on reading lord dunsany’s book of wonder             The hours of night unheeded fly,\n \tAnd in t...
# on receiving a picture of swans                      With pensive grace the melancholy Swan\n Mour...
# pacifist war song—1917                               We are the valiant Knights of Peace\n \tWho p...
# poemata minora, volume ii                            Ode to Selene or Diana\n \n Immortal Moon, in...
# providence                                           Where bay and river tranquil blend,\n \tAnd l...
# psychopompos                                         I am He who howls in the night;\n \tI am He w...
# revelation                                           In a vale of light and laughter,\n \tShining ...
# sunset                                               The cloudless day is richer at its close;\n \...
# the ancient track                                    There was no hand to hold me back\n That nigh...
# the cats                                             Babels of blocks to the high heavens tow’ring...
# the city                                             \tIt was golden and splendid,\n \t\tThat City...
# the conscript                                        I am a peaceful working man—\n \tI am not wis...
# the house                                            \t’Tis a grove-circled dwelling\n \t\tSet clo...
# the messenger                                        To Bertrand K. Hart, Esq.\n \n The thing, he ...
# the nightmare lake                                   There is a lake in distant Zan,\n Beyond the ...
# the outpost                                          When evening cools the yellow stream,\n \tAnd...
# the peace advocate                                   (Supposed to be a “pome,” but cast strictly i...
# the poe-et’s nightmare                               A Fable\n \n \tLuxus tumultus semper causa es...
# the rose of england                                  At morn the rosebud greets the sun\n \tAnd sh...
# the wood                                             They cut it down, and where the pitch-black a...
# to clark ashton smith, esq., upon his phantasti...   A time-black tower against dim banks of cloud...
# to edward john moreton drax plunkett, eighteent...   As when the sun above a dusky wold\n Springs ...
# unda; or, the bride of the sea                       Respectfully Dedicated with Permission to MAU...
# waste paper a poem of profound insignificance        Πἀντα γἐλως καἱ πἀντα κὀνις καἱ πἀντα τὁ μηδἐ...
#
#                                                    category  \
# title
# a garden                                               poem
# an american to mother england                          poem
# arcadia                                                poem
# astrophobos                                            poem
# christmas                                              poem
# dead passion's flame                                   poem
# despair                                                poem
# fact and fancy                                         poem
# festival                                               poem
# fungi from yuggoth                                     poem
# hallowe'en in a suburb                                 poem
# in a sequester’d providence churchyard where on...     poem
# laeta; a lament                                        poem
# life’s mystery                                         poem
# lines on gen. robert edward lee                        poem
# nathicana                                              poem
# nemesis                                                poem
# ode for july fourth, 1917                              poem
# on reading lord dunsany’s book of wonder               poem
# on receiving a picture of swans                        poem
# pacifist war song—1917                                 poem
# poemata minora, volume ii                              poem
# providence                                             poem
# psychopompos                                           poem
# revelation                                             poem
# sunset                                                 poem
# the ancient track                                      poem
# the cats                                               poem
# the city                                               poem
# the conscript                                          poem
# the house                                              poem
# the messenger                                          poem
# the nightmare lake                                     poem
# the outpost                                            poem
# the peace advocate                                     poem
# the poe-et’s nightmare                                 poem
# the rose of england                                    poem
# the wood                                               poem
# to clark ashton smith, esq., upon his phantasti...     poem
# to edward john moreton drax plunkett, eighteent...     poem
# unda; or, the bride of the sea                         poem
# waste paper a poem of profound insignificance          poem
#
#                                                                                              filepath  \
# title
# a garden                                                                     data/poetry\A Garden.txt
# an american to mother england                           data/poetry\An American to Mother England.txt
# arcadia                                                                       data/poetry\Arcadia.txt
# astrophobos                                                               data/poetry\Astrophobos.txt
# christmas                                                                   data/poetry\Christmas.txt
# dead passion's flame                                             data/poetry\Dead Passion's Flame.txt
# despair                                                                       data/poetry\Despair.txt
# fact and fancy                                                         data/poetry\Fact and Fancy.txt
# festival                                                                     data/poetry\Festival.txt
# fungi from yuggoth                                                 data/poetry\Fungi from Yuggoth.txt
# hallowe'en in a suburb                                         data/poetry\Hallowe'en in a Suburb.txt
# in a sequester’d providence churchyard where on...  data/poetry\In a Sequester’d Providence Church...
# laeta; a lament                                                       data/poetry\Laeta; a Lament.txt
# life’s mystery                                                         data/poetry\Life's Mystery.txt
# lines on gen. robert edward lee                       data/poetry\Lines on Gen. Robert Edward Lee.txt
# nathicana                                                                   data/poetry\Nathicana.txt
# nemesis                                                                       data/poetry\Nemesis.txt
# ode for july fourth, 1917                                   data/poetry\Ode for July Fourth, 1917.txt
# on reading lord dunsany’s book of wonder            data/poetry\On Reading Lord Dunsany’s Book of ...
# on receiving a picture of swans                       data/poetry\On Receiving a Picture of Swans.txt
# pacifist war song—1917                                         data/poetry\Pacifist War Song—1917.txt
# poemata minora, volume ii                                   data/poetry\Poemata Minora, Volume II.txt
# providence                                                                 data/poetry\Providence.txt
# psychopompos                                             data/poetry\Psychopompos A Tale in Rhyme.txt
# revelation                                                                 data/poetry\Revelation.txt
# sunset                                                                         data/poetry\Sunset.txt
# the ancient track                                                   data/poetry\The Ancient Track.txt
# the cats                                                                     data/poetry\The Cats.txt
# the city                                                                     data/poetry\The City.txt
# the conscript                                                           data/poetry\The Conscript.txt
# the house                                                                   data/poetry\The House.txt
# the messenger                                                           data/poetry\The Messenger.txt
# the nightmare lake                                                 data/poetry\The Nightmare Lake.txt
# the outpost                                                               data/poetry\The Outpost.txt
# the peace advocate                                                 data/poetry\The Peace Advocate.txt
# the poe-et’s nightmare                                         data/poetry\The Poe-et’s Nightmare.txt
# the rose of england                                               data/poetry\The Rose of England.txt
# the wood                                                                     data/poetry\The Wood.txt
# to clark ashton smith, esq., upon his phantasti...  data/poetry\To Clark Ashton Smith, Esq., upon ...
# to edward john moreton drax plunkett, eighteent...  data/poetry\To Edward John Moreton Drax Plunke...
# unda; or, the bride of the sea                         data/poetry\Unda; or, The Bride of the Sea.txt
# waste paper a poem of profound insignificance                             data/poetry\Waste Paper.txt
#
#                                                     date
# title
# a garden                                            1917
# an american to mother england                       1916
# arcadia                                             1935
# astrophobos                                         1917
# christmas                                           1920
# dead passion's flame                                1935
# despair                                             1919
# fact and fancy                                      1917
# festival                                            1925
# fungi from yuggoth                                  1930
# hallowe'en in a suburb                              1926
# in a sequester’d providence churchyard where on...  1936
# laeta; a lament                                     1918
# life’s mystery                                       N.D
# lines on gen. robert edward lee                     1916
# nathicana                                           1927
# nemesis                                             1917
# ode for july fourth, 1917                           1917
# on reading lord dunsany’s book of wonder            1920
# on receiving a picture of swans                     1915
# pacifist war song—1917                              1917
# poemata minora, volume ii                           1902
# providence                                          1912
# psychopompos                                        1918
# revelation                                          1919
# sunset                                              1917
# the ancient track                                   1929
# the cats                                            1925
# the city                                            1919
# the conscript                                       1918
# the house                                           1919
# the messenger                                       1929
# the nightmare lake                                  1919
# the outpost                                         1929
# the peace advocate                                  1917
# the poe-et’s nightmare                              1916
# the rose of england                                 1916
# the wood                                            1929
# to clark ashton smith, esq., upon his phantasti...  1936
# to edward john moreton drax plunkett, eighteent...  1919
# unda; or, the bride of the sea                      1915
# waste paper a poem of profound insignificance       1923

# %%
hp_df = hp_df.append(poems_df)

# %% [markdown]
# I am going to save one file without the raw text content as the LIB file, and another that drops the category and date columns as a RAW file. This way I can conform to the F2 style and also retain the raw text as a csv.

# %%
LIB = hp_df.copy()
LIB.drop('content', axis=1, inplace=True)
LIB.to_csv('data/output/lovecraft_LIB.csv')

# %%
RAW = hp_df.copy()
RAW.drop(['category', 'date'], axis=1, inplace=True)
RAW.to_csv('data/output/lovecraft_RAW.csv', index=False)

# %%
# load these dataframes back if the kernal disconnects or is shut off.
LIB = pd.read_csv('data/output/lovecraft_LIB.csv')
RAW = pd.read_csv('data/output/lovecraft_RAW.csv')

# %% [markdown]
# ---

# %% [markdown]
# # 2) From F0 to F2

# %%
tokenizable_df = hp_df.copy()

# %%
def tokenize(dataframe):
    pass


def preprocess(dataframe):
    '''Preprocesses the text for tokenization'''
    temp = dataframe.copy()
    for i in ['\n', '\t']:
        temp.content.apply(lambda x: x.replace(i, ''))
    return temp

# %%
#tokenizable_df.content = tokenizable_df.content.str.lower()
tokenizable_df = tokenizable_df.replace(['\n', '\t'], ' ', regex=True)

# %%
#tokenizable_df['content'] = tokenizable_df['content'].str.replace('[^\w\s]', '', regex=True)

# %%
tokenizable_df
# Out:
#                                                                                               content  \
# title
# the alchemist                                        High up, crowning the grassy summit of a swel...
# facts concerning the late arthur jermyn and his...   I  Life is a hideous thing, and from the back...
# azathoth                                             When age fell upon the world, and wonder went...
# the beast in the cave                                The horrible conclusion which had been gradua...
# beyond the wall of sleep                             I have often wondered if the majority of mank...
# ...                                                                                               ...
# the wood                                             They cut it down, and where the pitch-black a...
# to clark ashton smith, esq., upon his phantasti...   A time-black tower against dim banks of cloud...
# to edward john moreton drax plunkett, eighteent...   As when the sun above a dusky wold  Springs i...
# unda; or, the bride of the sea                       Respectfully Dedicated with Permission to MAU...
# waste paper a poem of profound insignificance        Πἀντα γἐλως καἱ πἀντα κὀνις καἱ πἀντα τὁ μηδἐ...
#
#                                                                                              filepath  \
# title
# the alchemist                                                        data/short_stories\alchemist.txt
# facts concerning the late arthur jermyn and his...               data/short_stories\arthur_jermyn.txt
# azathoth                                                              data/short_stories\azathoth.txt
# the beast in the cave                                                    data/short_stories\beast.txt
# beyond the wall of sleep                                  data/short_stories\beyond_wall_of_sleep.txt
# ...                                                                                               ...
# the wood                                                                     data/poetry\The Wood.txt
# to clark ashton smith, esq., upon his phantasti...  data/poetry\To Clark Ashton Smith, Esq., upon ...
# to edward john moreton drax plunkett, eighteent...  data/poetry\To Edward John Moreton Drax Plunke...
# unda; or, the bride of the sea                         data/poetry\Unda; or, The Bride of the Sea.txt
# waste paper a poem of profound insignificance                             data/poetry\Waste Paper.txt
#
#                                                     date     category
# title
# the alchemist                                       1908  short story
# facts concerning the late arthur jermyn and his...  1920  short story
# azathoth                                            1922  short story
# the beast in the cave                               1905  short story
# beyond the wall of sleep                            1919  short story
# ...                                                  ...          ...
# the wood                                            1929         poem
# to clark ashton smith, esq., upon his phantasti...  1936         poem
# to edward john moreton drax plunkett, eighteent...  1919         poem
# unda; or, the bride of the sea                      1915         poem
# waste paper a poem of profound insignificance       1923         poem
#
# [109 rows x 4 columns]

# %%
tokenizable_df['content_lower'] = tokenizable_df['content'].str.lower()

# %%
TOKENS = pd.DataFrame(columns=['title', 'sent_num', 'token_num', 'tokens_str', 'term_str'])

# %%
TOKENS
# Out:
# Empty DataFrame
# Columns: [title, sent_num, token_num, tokens_str, term_str]
# Index: []

# %% [markdown]
# # F2 to F4

# %% [markdown]
# ### Part of speech tagging.

# %% [markdown]
# This will take a while...

# %%
cols = ['title', 'para_num', 'sent_num', 'token_num', 'pos_tuple', 'pos', 'token_str', 'term_str']
CORPUS = pd.DataFrame(columns=cols)

for work in tqdm(range(len(tokenizable_df))):
    work_df = pd.DataFrame(columns=cols)
    paras = tokenizable_df.iloc[work].content.split('\n \n')
    title = str(tokenizable_df.index[work])
    for para in range(len(paras)):
        sentence = nltk.sent_tokenize(paras[para])
        for sent in range(len(sentence)):
            tokens = nltk.word_tokenize(sentence[sent])
            tag = nltk.pos_tag(tokens)
            new_row = {}
            for token in range(len(tag)):
                new_row['title'] = title
                new_row['para_num'] = para
                new_row['sent_num'] = sent
                new_row['token_num'] = token
                new_row['pos_tuple'] = str(tag[token])
                new_row['pos'] = tag[token][1]
                new_row['token_str'] = tag[token][0]
                new_row['term_str'] = new_row['token_str'].lower()
                temp = pd.DataFrame(new_row, columns=cols, index=[0])
                work_df = pd.concat([work_df, temp])
    CORPUS = pd.concat([CORPUS, work_df])
# Out:
# 100%|██████████| 109/109 [43:37<00:00, 24.01s/it]

# %%
CORPUS
# Out:
#                                             title para_num sent_num token_num  \
# 0                                   the alchemist        0        0         0
# 0                                   the alchemist        0        0         1
# 0                                   the alchemist        0        0         2
# 0                                   the alchemist        0        0         3
# 0                                   the alchemist        0        0         4
# ..                                            ...      ...      ...       ...
# 0   waste paper a poem of profound insignificance        0       59         1
# 0   waste paper a poem of profound insignificance        0       59         2
# 0   waste paper a poem of profound insignificance        0       59         3
# 0   waste paper a poem of profound insignificance        0       59         4
# 0   waste paper a poem of profound insignificance        0       59         5
#
#               pos_tuple  pos token_str  term_str
# 0       ('High', 'NNP')  NNP      High      high
# 0          ('up', 'RB')   RB        up        up
# 0            (',', ',')    ,         ,         ,
# 0   ('crowning', 'VBG')  VBG  crowning  crowning
# 0         ('the', 'DT')   DT       the       the
# ..                  ...  ...       ...       ...
# 0        ('home', 'NN')   NN      home      home
# 0          ('In', 'IN')   IN        In        in
# 0         ('the', 'DT')   DT       the       the
# 0     ('shantih', 'NN')   NN   shantih   shantih
# 0            ('.', '.')    .         .         .
#
# [585824 rows x 8 columns]

# %% [markdown]
# ### Part of speech group from part of speech

# %%
CORPUS['pos_group'] = CORPUS['pos'].apply(lambda x: x[:2])

# %%
CORPUS
# Out:
#                                             title para_num sent_num token_num  \
# 0                                   the alchemist        0        0         0
# 0                                   the alchemist        0        0         1
# 0                                   the alchemist        0        0         2
# 0                                   the alchemist        0        0         3
# 0                                   the alchemist        0        0         4
# ..                                            ...      ...      ...       ...
# 0   waste paper a poem of profound insignificance        0       59         1
# 0   waste paper a poem of profound insignificance        0       59         2
# 0   waste paper a poem of profound insignificance        0       59         3
# 0   waste paper a poem of profound insignificance        0       59         4
# 0   waste paper a poem of profound insignificance        0       59         5
#
#               pos_tuple  pos token_str  term_str pos_group
# 0       ('High', 'NNP')  NNP      High      high        NN
# 0          ('up', 'RB')   RB        up        up        RB
# 0            (',', ',')    ,         ,         ,         ,
# 0   ('crowning', 'VBG')  VBG  crowning  crowning        VB
# 0         ('the', 'DT')   DT       the       the        DT
# ..                  ...  ...       ...       ...       ...
# 0        ('home', 'NN')   NN      home      home        NN
# 0          ('In', 'IN')   IN        In        in        IN
# 0         ('the', 'DT')   DT       the       the        DT
# 0     ('shantih', 'NN')   NN   shantih   shantih        NN
# 0            ('.', '.')    .         .         .         .
#
# [585824 rows x 9 columns]

# %%
CORPUS[CORPUS.term_str == '']
# Out:
# Empty DataFrame
# Columns: [title, para_num, sent_num, token_num, pos_tuple, pos, token_str, term_str, pos_group]
# Index: []

# %% [markdown]
# No anomalies.

# %% [markdown]
# Saving.

# %%
CORPUS.to_csv('data/output/lovecraft_CORPUS.csv', index=False)

# %%
# load the corpus table if the kernal disconnects or is shut down.
CORPUS = pd.read_csv('data/output/lovecraft_CORPUS.csv')

# %% [markdown]
# ## Vocab Table

# %%
# This code comes from Dr Alvarado's ETA github repo.
def extract_vocab(TOKENS):
        """This should also be done at the corpus level."""
        VOCAB = TOKENS.copy()
        VOCAB = TOKENS.term_str.value_counts().to_frame('n')
        VOCAB.index.name = 'term_str'
        VOCAB['n_chars'] = VOCAB.index.str.len()
        VOCAB['p'] = VOCAB['n'] / VOCAB['n'].sum()
        VOCAB['s'] = 1 / VOCAB['p']
        VOCAB['i'] = np.log2(VOCAB['s']) # Same as negative log probability (i.e. log likelihood)
        VOCAB['h'] = VOCAB['p'] * VOCAB['i']
        H = VOCAB['h'].sum()
        return VOCAB
VOCAB = extract_vocab(CORPUS[['title', 'token_str', 'term_str']])

# %%
VOCAB = VOCAB.reset_index()

# %% [markdown]
# ### Adding Term Rank

# %%
rank_dict = {}
n_list = list(VOCAB.n.unique())
for i in range(len(n_list)):
    rank_dict[n_list[i]] = i+1

# %%
VOCAB['term_rank'] = VOCAB['n'].apply(lambda x: rank_dict[x])

# %%
VOCAB
# Out:
#           term_str      n  n_chars         p              s          i  \
# 0              the  36221        3  0.061829      16.173601   4.015569
# 1                ,  28309        1  0.048323      20.693914   4.371135
# 2              and  20776        3  0.035465      28.197151   4.817477
# 3               of  19688        2  0.033607      29.755384   4.895079
# 4                .  18392        1  0.031395      31.852110   4.993317
# ...            ...    ...      ...       ...            ...        ...
# 27565    hand-held      1        9  0.000002  585824.000000  19.160108
# 27566      maouths      1        7  0.000002  585824.000000  19.160108
# 27567      gammell      1        7  0.000002  585824.000000  19.160108
# 27568  sojournings      1       11  0.000002  585824.000000  19.160108
# 27569   druid-folk      1       10  0.000002  585824.000000  19.160108
#
#               h  term_rank
# 0      0.248279          1
# 1      0.211228          2
# 2      0.170850          3
# 3      0.164511          4
# 4      0.156766          5
# ...         ...        ...
# 27565  0.000033        421
# 27566  0.000033        421
# 27567  0.000033        421
# 27568  0.000033        421
# 27569  0.000033        421
#
# [27570 rows x 8 columns]

# %% [markdown]
# ### Stemming

# %%
porter = nltk.stem.PorterStemmer()
snowball = nltk.stem.SnowballStemmer(language='english')
lancaster = nltk.stem.LancasterStemmer()

VOCAB['stem_porter'] = VOCAB['term_str'].apply(lambda x: porter.stem(x))
VOCAB['stem_snowball'] = VOCAB['term_str'].apply(lambda x: snowball.stem(x))
VOCAB['stem_lancaster'] = VOCAB['term_str'].apply(lambda x: lancaster.stem(x))

# %%
VOCAB
# Out:
#           term_str      n  n_chars         p              s          i  \
# 0              the  36221        3  0.061829      16.173601   4.015569
# 1                ,  28309        1  0.048323      20.693914   4.371135
# 2              and  20776        3  0.035465      28.197151   4.817477
# 3               of  19688        2  0.033607      29.755384   4.895079
# 4                .  18392        1  0.031395      31.852110   4.993317
# ...            ...    ...      ...       ...            ...        ...
# 27565    hand-held      1        9  0.000002  585824.000000  19.160108
# 27566      maouths      1        7  0.000002  585824.000000  19.160108
# 27567      gammell      1        7  0.000002  585824.000000  19.160108
# 27568  sojournings      1       11  0.000002  585824.000000  19.160108
# 27569   druid-folk      1       10  0.000002  585824.000000  19.160108
#
#               h  term_rank stem_porter stem_snowball stem_lancaster
# 0      0.248279          1         the           the            the
# 1      0.211228          2           ,             ,              ,
# 2      0.170850          3         and           and            and
# 3      0.164511          4          of            of             of
# 4      0.156766          5           .             .              .
# ...         ...        ...         ...           ...            ...
# 27565  0.000033        421   hand-held     hand-held      hand-held
# 27566  0.000033        421      maouth        maouth         maouth
# 27567  0.000033        421      gammel        gammel         gammel
# 27568  0.000033        421     sojourn       sojourn        sojourn
# 27569  0.000033        421  druid-folk    druid-folk     druid-folk
#
# [27570 rows x 11 columns]

# %% [markdown]
# ### Adding Max POS

# %%
VOCAB['max_pos'] = CORPUS[['term_str', 'pos']].value_counts().unstack(fill_value=0).idxmax(1)

# %%
# Out:
#        term_str max_pos
# 0             !       .
# 1             #       #
# 2             $       $
# 3             &      CC
# 4             '      ''
# ...         ...     ...
# 27565  —maevius     NNP
# 27566      —now     VBP
# 27567         ’     NNP
# 27568         “      NN
# 27569         ”      NN
#
# [27570 rows x 2 columns]

# %%
temp = VOCAB.copy()
temp = temp.merge(pd.DataFrame(CORPUS[['term_str', 'pos']].value_counts().unstack(fill_value=0).idxmax(1), 
                        columns=['max_pos']).reset_index(),
                  on='term_str',
                  how='left')
temp['max_pos'] = temp['max_pos_y']
temp.drop(['max_pos_x', 'max_pos_y'], inplace=True, axis=1)
VOCAB = temp.copy()

# %%
temp = VOCAB.copy()
temp = temp.merge(pd.DataFrame(CORPUS[['term_str','pos']].value_counts().unstack().count(1), 
                        columns=['n_pos']).reset_index(),
                  on='term_str',
                  how='left')
temp['n_pos'] = temp['n_pos_y']
temp.drop(['n_pos_x', 'n_pos_y'], inplace=True, axis=1)
VOCAB = temp.copy()

# %%
VOCAB
# Out:
#           term_str      n  n_chars         p              s          i  \
# 0              the  36221        3  0.061829      16.173601   4.015569
# 1                ,  28309        1  0.048323      20.693914   4.371135
# 2              and  20776        3  0.035465      28.197151   4.817477
# 3               of  19688        2  0.033607      29.755384   4.895079
# 4                .  18392        1  0.031395      31.852110   4.993317
# ...            ...    ...      ...       ...            ...        ...
# 27565    hand-held      1        9  0.000002  585824.000000  19.160108
# 27566      maouths      1        7  0.000002  585824.000000  19.160108
# 27567      gammell      1        7  0.000002  585824.000000  19.160108
# 27568  sojournings      1       11  0.000002  585824.000000  19.160108
# 27569   druid-folk      1       10  0.000002  585824.000000  19.160108
#
#               h  term_rank stem_porter stem_snowball stem_lancaster max_pos  \
# 0      0.248279          1         the           the            the      DT
# 1      0.211228          2           ,             ,              ,       ,
# 2      0.170850          3         and           and            and      CC
# 3      0.164511          4          of            of             of      IN
# 4      0.156766          5           .             .              .       .
# ...         ...        ...         ...           ...            ...     ...
# 27565  0.000033        421   hand-held     hand-held      hand-held      NN
# 27566  0.000033        421      maouth        maouth         maouth     NNS
# 27567  0.000033        421      gammel        gammel         gammel     NNP
# 27568  0.000033        421     sojourn       sojourn        sojourn     NNS
# 27569  0.000033        421  druid-folk    druid-folk     druid-folk     NNP
#
#        n_pos
# 0          2
# 1          1
# 2          2
# 3          2
# 4          1
# ...      ...
# 27565      1
# 27566      1
# 27567      1
# 27568      1
# 27569      1
#
# [27570 rows x 13 columns]

# %% [markdown]
# ### Stopwords

# %%
sw = pd.DataFrame(nltk.corpus.stopwords.words('english'), columns=['term_str'])
sw = sw.reset_index().set_index('term_str')
sw.columns = ['dummy']
sw.dummy = 1

# %%
VOCAB['stop'] = VOCAB['term_str'].apply(lambda x: 1 if x in list(sw.reset_index()['term_str']) else 0)

# %%
VOCAB[VOCAB['stop'] == 1]
# Out:
#          term_str      n  n_chars         p              s          i  \
# 0             the  36221        3  0.061829      16.173601   4.015569
# 2             and  20776        3  0.035465      28.197151   4.817477
# 3              of  19688        2  0.033607      29.755384   4.895079
# 5              to  11063        2  0.018885      52.953448   5.726653
# 6               a  10452        1  0.017842      56.048986   5.808616
# ...           ...    ...      ...       ...            ...        ...
# 11882          re      3        2  0.000005  195274.666667  17.575145
# 13859         don      2        3  0.000003  292912.000000  18.160108
# 15577        didn      2        4  0.000003  292912.000000  18.160108
# 21910           m      1        1  0.000002  585824.000000  19.160108
# 25628  yourselves      1       10  0.000002  585824.000000  19.160108
#
#               h  term_rank stem_porter stem_snowball stem_lancaster max_pos  \
# 0      0.248279          1         the           the            the      DT
# 2      0.170850          3         and           and            and      CC
# 3      0.164511          4          of            of             of      IN
# 5      0.108145          6          to            to             to      TO
# 6      0.103635          7           a             a              a      DT
# ...         ...        ...         ...           ...            ...     ...
# 11882  0.000090        419          re            re             re     NNP
# 13859  0.000062        420         don           don            don      VB
# 15577  0.000062        420        didn          didn           didn     VBP
# 21910  0.000033        421           m             m              m      JJ
# 25628  0.000033        421    yourselv      yourselv       yourselv     NNS
#
#        n_pos  stop
# 0          2     1
# 2          2     1
# 3          2     1
# 5          2     1
# 6          2     1
# ...      ...   ...
# 11882      3     1
# 13859      1     1
# 15577      2     1
# 21910      1     1
# 25628      1     1
#
# [138 rows x 14 columns]

# %%
VOCAB[VOCAB['max_pos'].isna()]
# Out:
# Empty DataFrame
# Columns: [term_str, n, n_chars, p, s, i, h, term_rank, stem_porter, stem_snowball, stem_lancaster, max_pos, n_pos, stop]
# Index: []

# %% [markdown]
# ### Zipf's k

# %%
VOCAB['zipf_k'] = VOCAB.n * VOCAB.term_rank

# %%
VOCAB
# Out:
#           term_str      n  n_chars         p              s          i  \
# 0              the  36221        3  0.061829      16.173601   4.015569
# 1                ,  28309        1  0.048323      20.693914   4.371135
# 2              and  20776        3  0.035465      28.197151   4.817477
# 3               of  19688        2  0.033607      29.755384   4.895079
# 4                .  18392        1  0.031395      31.852110   4.993317
# ...            ...    ...      ...       ...            ...        ...
# 27565    hand-held      1        9  0.000002  585824.000000  19.160108
# 27566      maouths      1        7  0.000002  585824.000000  19.160108
# 27567      gammell      1        7  0.000002  585824.000000  19.160108
# 27568  sojournings      1       11  0.000002  585824.000000  19.160108
# 27569   druid-folk      1       10  0.000002  585824.000000  19.160108
#
#               h  term_rank stem_porter stem_snowball stem_lancaster max_pos  \
# 0      0.248279          1         the           the            the      DT
# 1      0.211228          2           ,             ,              ,       ,
# 2      0.170850          3         and           and            and      CC
# 3      0.164511          4          of            of             of      IN
# 4      0.156766          5           .             .              .       .
# ...         ...        ...         ...           ...            ...     ...
# 27565  0.000033        421   hand-held     hand-held      hand-held      NN
# 27566  0.000033        421      maouth        maouth         maouth     NNS
# 27567  0.000033        421      gammel        gammel         gammel     NNP
# 27568  0.000033        421     sojourn       sojourn        sojourn     NNS
# 27569  0.000033        421  druid-folk    druid-folk     druid-folk     NNP
#
#        n_pos  stop  zipf_k
# 0          2     1   36221
# 1          1     0   56618
# 2          2     1   62328
# 3          2     1   78752
# 4          1     0   91960
# ...      ...   ...     ...
# 27565      1     0     421
# 27566      1     0     421
# 27567      1     0     421
# 27568      1     0     421
# 27569      1     0     421
#
# [27570 rows x 15 columns]

# %% [markdown]
# ### TFIDF

# %% [markdown]
# #### Bag of Words

# %%
BOW = CORPUS.groupby(['title']+['term_str']).term_str.count().to_frame('n')

# %%
len(BOW)
# Out:
# 130334

# %%
BOW.sample(15)
# Out:
#                                               n
# title                             term_str
# the dream-quest of unknown kadath sculptured  1
# the rats in the walls             beings      1
# the very old folk                 become      2
# the picture in the house          hence       1
# the dunwich horror                pursuers    1
# the dreams in the witch house     lodgings    1
# the temple                        records     1
# the shunned house                 sickly      2
#                                   schooner    1
# imprisoned with the pharaohs      break       1
# the hound                         proceeded   1
# at the mountains of madness       capture     1
# beyond the wall of sleep          titanic     2
# at the mountains of madness       mazes       1
# herbert west: reanimator          public      5

# %% [markdown]
# #### Document Term Matrix

# %%
DTCM = BOW.n.unstack()

# %%
DTCM.columns[10000:10010]
# Out:
# Index(['fruitful', 'fruition', 'fruitless', 'fruitlessly', 'fruits',
#        'frustrated', 'frustration', 'fry', 'frye', 'fryes'],
#       dtype='object', name='term_str')

# %%
# Compute DF (Document Frequency)
DF = DTCM.count() # THIS WORKS IF WE KEPT NULLS IN DTCM

# Compute TF (Term Frequency)
tf_method = 'sum'
print('TF method:', tf_method)
if tf_method == 'sum':
    TF = DTCM.T / DTCM.T.sum()
elif tf_method == 'max':
    TF = DTCM.T / DTCM.T.max()
elif tf_method == 'log':
    TF = np.log10(DTCM.T + 1)
elif tf_method == 'raw':
    TF = DTCM.T
elif tf_method == 'bool':
    TF = DTCM.T.astype('bool') #.astype('int')
TF = TF.T

# Compute IDF (Inverse Document Frequency)
idf_method = 'standard'
N = DTCM.shape[0]
print('IDF method:', idf_method)
if idf_method == 'standard':
    IDF = np.log10(N / DF)
elif idf_method == 'max':
    IDF = np.log10(DF.max() / DF) 
elif idf_method == 'smooth':
    IDF = np.log10((1 + N) / (1 + DF)) + 1
    
# Compute TFIDF
TFIDF = TF * IDF
# Out:
# TF method: sum
# IDF method: standard

# %%
TFIDF.head()
# Out:
# term_str                              !   #   $   &         '        ''  '10  \
# title
# a garden                       0.000822 NaN NaN NaN       NaN       NaN  NaN
# an american to mother england  0.004340 NaN NaN NaN       NaN       NaN  NaN
# arcadia                             NaN NaN NaN NaN       NaN       NaN  NaN
# astrophobos                         NaN NaN NaN NaN       NaN       NaN  NaN
# at the mountains of madness    0.000083 NaN NaN NaN  0.000174  0.000298  NaN
#
# term_str                       '28  '45  '46  ...  κὀνις  μηδἐν  πἀντα  τὁ  \
# title                                         ...
# a garden                       NaN  NaN  NaN  ...    NaN    NaN    NaN NaN
# an american to mother england  NaN  NaN  NaN  ...    NaN    NaN    NaN NaN
# arcadia                        NaN  NaN  NaN  ...    NaN    NaN    NaN NaN
# astrophobos                    NaN  NaN  NaN  ...    NaN    NaN    NaN NaN
# at the mountains of madness    NaN  NaN  NaN  ...    NaN    NaN    NaN NaN
#
# term_str                       —lucan  —maevius  —now         ’   “   ”
# title
# a garden                          NaN       NaN   NaN  0.012538 NaN NaN
# an american to mother england     NaN       NaN   NaN  0.020480 NaN NaN
# arcadia                           NaN       NaN   NaN       NaN NaN NaN
# astrophobos                       NaN       NaN   NaN  0.028308 NaN NaN
# at the mountains of madness       NaN       NaN   NaN       NaN NaN NaN
#
# [5 rows x 27570 columns]

# %%
df = pd.DataFrame(DF, columns=['df']).reset_index().copy()

temp = VOCAB.copy()
temp = temp.merge(df, on='term_str', how='left')
VOCAB = temp.copy()

# %%
idf = pd.DataFrame(IDF, columns=['idf']).reset_index().copy()

temp = VOCAB.copy()
temp = temp.merge(idf, on='term_str', how='left')
VOCAB = temp.copy()

# %% [markdown]
# #### TFIDF aggregates

# %%
tfidf_mean = pd.DataFrame(TFIDF[TFIDF > 0].mean().fillna(0), columns=['tfidf_mean']).reset_index().copy()

temp = VOCAB.copy()
temp = temp.merge(tfidf_mean, on='term_str', how='left')
VOCAB = temp.copy()

# %%
VOCAB['tfidf_max'] = TFIDF.max()

tfidf_max = pd.DataFrame(TFIDF.max(), columns=['tfidf_max']).reset_index().copy()
temp = VOCAB.copy()
temp = temp.merge(tfidf_max, on='term_str', how='left')
temp.rename(columns={'tfidf_max_y': 'tfidf_max'}, inplace=True)
temp.drop(['tfidf_max_x'], axis=1, inplace=True)
temp = temp.loc[:,~temp.columns.duplicated()]
temp
#VOCAB = temp.copy()
# Out:
#           term_str      n  n_chars         p              s          i  \
# 0              the  36221        3  0.061829      16.173601   4.015569
# 1                ,  28309        1  0.048323      20.693914   4.371135
# 2              and  20776        3  0.035465      28.197151   4.817477
# 3               of  19688        2  0.033607      29.755384   4.895079
# 4                .  18392        1  0.031395      31.852110   4.993317
# ...            ...    ...      ...       ...            ...        ...
# 27565    hand-held      1        9  0.000002  585824.000000  19.160108
# 27566      maouths      1        7  0.000002  585824.000000  19.160108
# 27567      gammell      1        7  0.000002  585824.000000  19.160108
# 27568  sojournings      1       11  0.000002  585824.000000  19.160108
# 27569   druid-folk      1       10  0.000002  585824.000000  19.160108
#
#               h  term_rank stem_porter stem_snowball  ... zipf_k df_x  \
# 0      0.248279          1         the           the  ...  36221  109
# 1      0.211228          2           ,             ,  ...  56618  109
# 2      0.170850          3         and           and  ...  62328  108
# 3      0.164511          4          of            of  ...  78752  108
# 4      0.156766          5           .             .  ...  91960  107
# ...         ...        ...         ...           ...  ...    ...  ...
# 27565  0.000033        421   hand-held     hand-held  ...    421    1
# 27566  0.000033        421      maouth        maouth  ...    421    1
# 27567  0.000033        421      gammel        gammel  ...    421    1
# 27568  0.000033        421     sojourn       sojourn  ...    421    1
# 27569  0.000033        421  druid-folk    druid-folk  ...    421    1
#
#           idf_x  tfidf_mean_x  tfidf_max     dfidf    dfidf2  df_y     idf_y  \
# 0      0.000000      0.000000   0.000000  0.000000  0.000000   109  0.000000
# 1      0.000000      0.000000   0.000000  0.000000  0.000000   109  0.000000
# 2      0.004003      0.000151   0.000276  0.432296  0.003966   108  0.004003
# 3      0.004003      0.000127   0.000243  0.432296  0.003966   108  0.004003
# 4      0.008043      0.000250   0.002298  0.860571  0.007895   107  0.008043
# ...         ...           ...        ...       ...       ...   ...       ...
# 27565  2.037426      0.000072   0.000072  2.037426  0.018692     1  2.037426
# 27566  2.037426      0.000103   0.000103  2.037426  0.018692     1  2.037426
# 27567  2.037426      0.000154   0.000154  2.037426  0.018692     1  2.037426
# 27568  2.037426      0.000170   0.000170  2.037426  0.018692     1  2.037426
# 27569  2.037426      0.012200   0.012200  2.037426  0.018692     1  2.037426
#
#        tfidf_mean_y
# 0          0.000000
# 1          0.000000
# 2          0.000151
# 3          0.000127
# 4          0.000250
# ...             ...
# 27565      0.000072
# 27566      0.000103
# 27567      0.000154
# 27568      0.000170
# 27569      0.012200
#
# [27570 rows x 24 columns]

# %%
VOCAB[VOCAB.tfidf_max.isna()]
# Out:
#           term_str      n  n_chars         p              s          i  \
# 0              the  36221        3  0.061829      16.173601   4.015569
# 1                ,  28309        1  0.048323      20.693914   4.371135
# 2              and  20776        3  0.035465      28.197151   4.817477
# 3               of  19688        2  0.033607      29.755384   4.895079
# 4                .  18392        1  0.031395      31.852110   4.993317
# ...            ...    ...      ...       ...            ...        ...
# 27565    hand-held      1        9  0.000002  585824.000000  19.160108
# 27566      maouths      1        7  0.000002  585824.000000  19.160108
# 27567      gammell      1        7  0.000002  585824.000000  19.160108
# 27568  sojournings      1       11  0.000002  585824.000000  19.160108
# 27569   druid-folk      1       10  0.000002  585824.000000  19.160108
#
#               h  term_rank stem_porter stem_snowball  ...     idf_x  \
# 0      0.248279          1         the           the  ...  0.000000
# 1      0.211228          2           ,             ,  ...  0.000000
# 2      0.170850          3         and           and  ...  0.004003
# 3      0.164511          4          of            of  ...  0.004003
# 4      0.156766          5           .             .  ...  0.008043
# ...         ...        ...         ...           ...  ...       ...
# 27565  0.000033        421   hand-held     hand-held  ...  2.037426
# 27566  0.000033        421      maouth        maouth  ...  2.037426
# 27567  0.000033        421      gammel        gammel  ...  2.037426
# 27568  0.000033        421     sojourn       sojourn  ...  2.037426
# 27569  0.000033        421  druid-folk    druid-folk  ...  2.037426
#
#       tfidf_mean_x  tfidf_max_x  tfidf_max_y     dfidf    dfidf2  df_y  \
# 0         0.000000          NaN     0.000000  0.000000  0.000000   109
# 1         0.000000          NaN     0.000000  0.000000  0.000000   109
# 2         0.000151          NaN     0.000276  0.432296  0.003966   108
# 3         0.000127          NaN     0.000243  0.432296  0.003966   108
# 4         0.000250          NaN     0.002298  0.860571  0.007895   107
# ...            ...          ...          ...       ...       ...   ...
# 27565     0.000072          NaN     0.000072  2.037426  0.018692     1
# 27566     0.000103          NaN     0.000103  2.037426  0.018692     1
# 27567     0.000154          NaN     0.000154  2.037426  0.018692     1
# 27568     0.000170          NaN     0.000170  2.037426  0.018692     1
# 27569     0.012200          NaN     0.012200  2.037426  0.018692     1
#
#           idf_y  tfidf_mean_y  tfidf_max
# 0      0.000000      0.000000        NaN
# 1      0.000000      0.000000        NaN
# 2      0.004003      0.000151        NaN
# 3      0.004003      0.000127        NaN
# 4      0.008043      0.000250        NaN
# ...         ...           ...        ...
# 27565  2.037426      0.000072        NaN
# 27566  2.037426      0.000103        NaN
# 27567  2.037426      0.000154        NaN
# 27568  2.037426      0.000170        NaN
# 27569  2.037426      0.012200        NaN
#
# [27570 rows x 26 columns]

# %%
VOCAB
# Out:
#           term_str      n  n_chars         p              s          i  \
# 0              the  36221        3  0.061829      16.173601   4.015569
# 1                ,  28309        1  0.048323      20.693914   4.371135
# 2              and  20776        3  0.035465      28.197151   4.817477
# 3               of  19688        2  0.033607      29.755384   4.895079
# 4                .  18392        1  0.031395      31.852110   4.993317
# ...            ...    ...      ...       ...            ...        ...
# 27565    hand-held      1        9  0.000002  585824.000000  19.160108
# 27566      maouths      1        7  0.000002  585824.000000  19.160108
# 27567      gammell      1        7  0.000002  585824.000000  19.160108
# 27568  sojournings      1       11  0.000002  585824.000000  19.160108
# 27569   druid-folk      1       10  0.000002  585824.000000  19.160108
#
#               h  term_rank stem_porter stem_snowball stem_lancaster max_pos  \
# 0      0.248279          1         the           the            the      DT
# 1      0.211228          2           ,             ,              ,       ,
# 2      0.170850          3         and           and            and      CC
# 3      0.164511          4          of            of             of      IN
# 4      0.156766          5           .             .              .       .
# ...         ...        ...         ...           ...            ...     ...
# 27565  0.000033        421   hand-held     hand-held      hand-held      NN
# 27566  0.000033        421      maouth        maouth         maouth     NNS
# 27567  0.000033        421      gammel        gammel         gammel     NNP
# 27568  0.000033        421     sojourn       sojourn        sojourn     NNS
# 27569  0.000033        421  druid-folk    druid-folk     druid-folk     NNP
#
#        n_pos  stop  zipf_k   df       idf  tfidf_mean  tfidf_max_x  \
# 0          2     1   36221  109  0.000000    0.000000          NaN
# 1          1     0   56618  109  0.000000    0.000000          NaN
# 2          2     1   62328  108  0.004003    0.000151          NaN
# 3          2     1   78752  108  0.004003    0.000127          NaN
# 4          1     0   91960  107  0.008043    0.000250          NaN
# ...      ...   ...     ...  ...       ...         ...          ...
# 27565      1     0     421    1  2.037426    0.000072          NaN
# 27566      1     0     421    1  2.037426    0.000103          NaN
# 27567      1     0     421    1  2.037426    0.000154          NaN
# 27568      1     0     421    1  2.037426    0.000170          NaN
# 27569      1     0     421    1  2.037426    0.012200          NaN
#
#        tfidf_max_y
# 0         0.000000
# 1         0.000000
# 2         0.000276
# 3         0.000243
# 4         0.002298
# ...            ...
# 27565     0.000072
# 27566     0.000103
# 27567     0.000154
# 27568     0.000170
# 27569     0.012200
#
# [27570 rows x 20 columns]

# %%
BOW['tf'] = TF.stack()
BOW['tfidf'] = TFIDF.stack()

# %% [markdown]
# #### DFIDF

# %%
VOCAB['dfidf'] = VOCAB.df * VOCAB.idf
VOCAB['dfidf2'] = VOCAB.df/N * VOCAB.idf

# %%
VOCAB
# Out:
#           term_str      n  n_chars         p              s          i  \
# 0              the  36221        3  0.061829      16.173601   4.015569
# 1                ,  28309        1  0.048323      20.693914   4.371135
# 2              and  20776        3  0.035465      28.197151   4.817477
# 3               of  19688        2  0.033607      29.755384   4.895079
# 4                .  18392        1  0.031395      31.852110   4.993317
# ...            ...    ...      ...       ...            ...        ...
# 27565    hand-held      1        9  0.000002  585824.000000  19.160108
# 27566      maouths      1        7  0.000002  585824.000000  19.160108
# 27567      gammell      1        7  0.000002  585824.000000  19.160108
# 27568  sojournings      1       11  0.000002  585824.000000  19.160108
# 27569   druid-folk      1       10  0.000002  585824.000000  19.160108
#
#               h  term_rank stem_porter stem_snowball  ... n_pos stop  zipf_k  \
# 0      0.248279          1         the           the  ...     2    1   36221
# 1      0.211228          2           ,             ,  ...     1    0   56618
# 2      0.170850          3         and           and  ...     2    1   62328
# 3      0.164511          4          of            of  ...     2    1   78752
# 4      0.156766          5           .             .  ...     1    0   91960
# ...         ...        ...         ...           ...  ...   ...  ...     ...
# 27565  0.000033        421   hand-held     hand-held  ...     1    0     421
# 27566  0.000033        421      maouth        maouth  ...     1    0     421
# 27567  0.000033        421      gammel        gammel  ...     1    0     421
# 27568  0.000033        421     sojourn       sojourn  ...     1    0     421
# 27569  0.000033        421  druid-folk    druid-folk  ...     1    0     421
#
#         df       idf  tfidf_mean  tfidf_max_x  tfidf_max_y     dfidf    dfidf2
# 0      109  0.000000    0.000000          NaN     0.000000  0.000000  0.000000
# 1      109  0.000000    0.000000          NaN     0.000000  0.000000  0.000000
# 2      108  0.004003    0.000151          NaN     0.000276  0.432296  0.003966
# 3      108  0.004003    0.000127          NaN     0.000243  0.432296  0.003966
# 4      107  0.008043    0.000250          NaN     0.002298  0.860571  0.007895
# ...    ...       ...         ...          ...          ...       ...       ...
# 27565    1  2.037426    0.000072          NaN     0.000072  2.037426  0.018692
# 27566    1  2.037426    0.000103          NaN     0.000103  2.037426  0.018692
# 27567    1  2.037426    0.000154          NaN     0.000154  2.037426  0.018692
# 27568    1  2.037426    0.000170          NaN     0.000170  2.037426  0.018692
# 27569    1  2.037426    0.012200          NaN     0.012200  2.037426  0.018692
#
# [27570 rows x 22 columns]

# %%
VOCAB[np.isnan(VOCAB['df'])]
# Out:
# Empty DataFrame
# Columns: [term_str, n, n_chars, p, s, i, h, term_rank, stem_porter, stem_snowball, stem_lancaster, max_pos, n_pos, stop, zipf_k, df, idf, tfidf_mean, tfidf_max_x, tfidf_max_y, dfidf, dfidf2]
# Index: []
#
# [0 rows x 22 columns]

# %%
(len(VOCAB) - len(VOCAB.dropna()))/len(VOCAB)
# Out:
# 1.0

# %%
len(VOCAB[[True if '-' in x else False for x in VOCAB.term_str]])/len(VOCAB)
# Out:
# 0.10214000725426188

# %%
VOCAB[[True if '-' in x else False for x in VOCAB.term_str]]
# Out:
#                term_str     n  n_chars         p              s          i  \
# 16                   --  3710        2  0.006333     157.904043   7.302904
# 866        night-gaunts    64       12  0.000109    9153.500000  13.160108
# 2177        yog-sothoth    25       11  0.000043   23432.960000  14.516252
# 2390        dylath-leen    23       11  0.000039   25470.608696  14.636546
# 2843        high-priest    19       11  0.000032   30832.842105  14.912180
# ...                 ...   ...      ...       ...            ...        ...
# 27551         worn-down     1        9  0.000002  585824.000000  19.160108
# 27555         ill-built     1        9  0.000002  585824.000000  19.160108
# 27556  singular-looking     1       16  0.000002  585824.000000  19.160108
# 27565         hand-held     1        9  0.000002  585824.000000  19.160108
# 27569        druid-folk     1       10  0.000002  585824.000000  19.160108
#
#               h  term_rank    stem_porter  stem_snowball  ... n_pos stop  \
# 16     0.046249         17             --             --  ...     1    0
# 866    0.001438        358    night-gaunt    night-gaunt  ...     1    0
# 2177   0.000619        397    yog-sothoth    yog-sothoth  ...     4    0
# 2390   0.000575        399    dylath-leen    dylath-leen  ...     2    0
# 2843   0.000484        403    high-priest    high-priest  ...     2    0
# ...         ...        ...            ...            ...  ...   ...  ...
# 27551  0.000033        421      worn-down      worn-down  ...     1    0
# 27555  0.000033        421      ill-built      ill-built  ...     1    0
# 27556  0.000033        421  singular-look  singular-look  ...     1    0
# 27565  0.000033        421      hand-held      hand-held  ...     1    0
# 27569  0.000033        421     druid-folk     druid-folk  ...     1    0
#
#        zipf_k  df       idf  tfidf_mean  tfidf_max_x  tfidf_max_y      dfidf  \
# 16      63070  62  0.245035    0.001322          NaN     0.005462  15.192158
# 866     22912   2  1.736397    0.001359          NaN     0.002351   3.472793
# 2177     9925   5  1.338456    0.000249          NaN     0.000878   6.692282
# 2390     9177   1  2.037426    0.001007          NaN     0.001007   2.037426
# 2843     7657   5  1.338456    0.001061          NaN     0.003450   6.692282
# ...       ...  ..       ...         ...          ...          ...        ...
# 27551     421   1  2.037426    0.000072          NaN     0.000072   2.037426
# 27555     421   1  2.037426    0.000045          NaN     0.000045   2.037426
# 27556     421   1  2.037426    0.000069          NaN     0.000069   2.037426
# 27565     421   1  2.037426    0.000072          NaN     0.000072   2.037426
# 27569     421   1  2.037426    0.012200          NaN     0.012200   2.037426
#
#          dfidf2
# 16     0.139378
# 866    0.031860
# 2177   0.061397
# 2390   0.018692
# 2843   0.061397
# ...         ...
# 27551  0.018692
# 27555  0.018692
# 27556  0.018692
# 27565  0.018692
# 27569  0.018692
#
# [2816 rows x 22 columns]

# %%
VOCAB.columns
# Out:
# Index(['term_str', 'n', 'n_chars', 'p', 's', 'i', 'h', 'term_rank',
#        'stem_porter', 'stem_snowball', 'stem_lancaster', 'max_pos', 'n_pos',
#        'stop', 'zipf_k', 'df', 'idf', 'tfidf_mean', 'tfidf_max_x',
#        'tfidf_max_y', 'dfidf', 'dfidf2'],
#       dtype='object')

# %% [markdown]
# ### Saving

# %%
TOKENS.to_csv('data/output/lovecraft_TOKENS.csv', index=False)
VOCAB.to_csv('data/output/lovecraft_VOCAB.csv', index=False)
CORPUS.to_csv('data/output/lovecraft_CORPUS.csv', index=False)

# %%
# Loading tables if kernel shuts off.
TOKENS = pd.read_csv('data/output/lovecraft_TOKENS.csv')
VOCAB = pd.read_csv('data/output/lovecraft_VOCAB.csv')
CORPUS = pd.read_csv('data/output/lovecraft_CORPUS.csv')

# %% [markdown]
# ---

# %%
# save all
TOKENS.to_csv('data/output/lovecraft_TOKENS.csv', index=False)
VOCAB.to_csv('data/output/lovecraft_VOCAB.csv', index=False)
RAW.to_csv('data/output/lovecraft_RAW.csv', index=False)
LIB.to_csv('data/output/lovecraft_LIB.csv', index=False)
TOKENS.to_csv('data/output/lovecraft_TOKENS.csv', index=False)

# %% [markdown]
# tracking psuedonyms

# %%
{'arcadia' : 'Head Balledup',
 'dead passion\'s flame' : 'Blank Frailty'}
